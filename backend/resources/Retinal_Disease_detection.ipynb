# %%
# !nvidia-smi
# Out:
# Tue Aug 19 07:24:53 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 91.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 106.0 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="dyY68vxYBl3amcowxpSw")
project = rf.workspace("suresh-beekhani-4xwsr").project("retinal-disease-detection-cfpzy-grrzo")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 75.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 116.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Retinal-Disease-detection-1 in yolov11:: 100%|██████████| 6246/6246 [00:00<00:00, 8549.22it/s]

# %%
from ultralytics import YOLO

# Load a pretrained YOLO11n model (Detection)
model = YOLO("yolo11s.pt")

# Train the model
train_results = model.train(
    data="/content/Retinal-Disease-detection-1/data.yaml",  # path to dataset YAML
    epochs=50,  # number of training epochs
    imgsz=640,  # training image size
    device=0,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.180 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # Inference

# %%
from IPython.display import Image

# %%
Image("/content/runs/detect/train/results.png", width=600)

# %%
model = YOLO('/content/runs/detect/train/weights/best.pt')
results = model("/content/Retinal-Disease-detection-1/valid/images/1213_left_jpg.rf.247a4bc8ef13f9b97a725b5ae7a796c1.jpg", save=True)
results[0].show()
# Out:
# image 1/1 /content/Retinal-Disease-detection-1/valid/images/1213_left_jpg.rf.247a4bc8ef13f9b97a725b5ae7a796c1.jpg: 640x640 1 Normal, 15.6ms
# Speed: 3.3ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
model = YOLO('/content/runs/detect/train/weights/best.pt')
results = model("/content/Retinal-Disease-detection-1/valid/images/cataract_097_png.rf.145cfd08b0eae975722951c09358bd1b.jpg", save=True)
results[0].show()
# Out:
# image 1/1 /content/Retinal-Disease-detection-1/valid/images/cataract_097_png.rf.145cfd08b0eae975722951c09358bd1b.jpg: 448x640 1 Cataracts, 47.2ms
# Speed: 2.5ms preprocess, 47.2ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict4
# <PIL.Image.Image image mode=RGB size=2592x1728>

# %%
model = YOLO('/content/runs/detect/train/weights/best.pt')
results = model("/content/Retinal-Disease-detection-1/valid/images/1215_right_jpg.rf.f2c52ec2d8c09be6c2d9242aa26efd49.jpg", save=True)
results[0].show()
# Out:
# image 1/1 /content/Retinal-Disease-detection-1/valid/images/1215_right_jpg.rf.f2c52ec2d8c09be6c2d9242aa26efd49.jpg: 640x640 1 Glaucoma, 15.6ms
# Speed: 2.7ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
from google.colab import files
files.download('/content/runs/detect/train/weights/best.pt')
